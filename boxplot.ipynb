# %%
# Dependencies
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
file=Path("Resources/City_council_housing_data_2018_2021.csv")
house=pd.read_csv(file,index_col=False)
house
# Out:
#     With train City Council_format2      City council  Year  \
# 0           No         Alpine Shire        Alpine S    2018
# 1           No         Alpine Shire        Alpine S    2019
# 2           No         Alpine Shire        Alpine S    2020
# 3           No         Alpine Shire        Alpine S    2021
# 4           No    Ararat Rural City  Ararat Rural C    2018
# ..         ...                  ...               ...   ...
# 315        Yes   Yarra Ranges Shire  Yarra Ranges S    2021
# 316         No   Yarriambiack Shire  Yarriambiack S    2018
# 317         No   Yarriambiack Shire  Yarriambiack S    2019
# 318         No   Yarriambiack Shire  Yarriambiack S    2020
# 319         No   Yarriambiack Shire  Yarriambiack S    2021
#
#      House Number of Sales  Unit/Apartment Number of Sales  \
# 0                      218                              64
# 1                      214                              44
# 2                      244                              47
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr
import seaborn as sns
import matplotlib.pyplot as plt

# Convert 'With train' column to numerical values: Yes=1, No=0
house['With train'] = house['With train'].map({'Yes': 1, 'No': 0})

# Now compute the correlation
correlation_coefficient, p_value = pearsonr(house['With train'], house['Total Number of Sales'])

print("Correlation Coefficient:", correlation_coefficient)
print("P-value:", p_value)

# Visualizing with a boxplot
sns.boxplot(x='With train', y='Total Number of Sales', data=house)
plt.show()
# Out:
# Correlation Coefficient: 0.4988597212348468
# P-value: 1.5414505529085208e-21
